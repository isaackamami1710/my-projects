# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
credit=pd.read_csv('C:/Users/USER/Desktop/UCI_Credit_Card.csv')
credit.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 4  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# ...

# %%
credit.shape
# Out:
# (30000, 25)

# %%
credit.describe().style.background_gradient(cmap="magma_r")
# Out:
# <style type="text/css">
# #T_c04f1_row0_col0, #T_c04f1_row0_col2, #T_c04f1_row0_col3, #T_c04f1_row0_col4, #T_c04f1_row0_col5, #T_c04f1_row0_col6, #T_c04f1_row0_col7, #T_c04f1_row0_col8, #T_c04f1_row0_col9, #T_c04f1_row0_col10, #T_c04f1_row0_col11, #T_c04f1_row0_col24, #T_c04f1_row7_col0, #T_c04f1_row7_col1, #T_c04f1_row7_col12, #T_c04f1_row7_col13, #T_c04f1_row7_col14, #T_c04f1_row7_col15, #T_c04f1_row7_col16, #T_c04f1_row7_col17, #T_c04f1_row7_col18, #T_c04f1_row7_col19, #T_c04f1_row7_col20, #T_c04f1_row7_col21, #T_c04f1_row7_col22, #T_c04f1_row7_col23 {
#   background-color: #000004;
#   color: #f1f1f1;
# }
# #T_c04f1_row0_col1, #T_c04f1_row2_col20 {
#   background-color: #fcf4b6;
#   color: #000000;
# }
# #T_c04f1_row0_col12 {
#   background-color: #feac76;
#   color: #000000;
# }
# #T_c04f1_row0_col13, #T_c04f1_row5_col14 {
#   background-color: #fed194;
#   color: #000000;
# }
# #T_c04f1_row0_col14 {
#   background-color: #fecd90;
#   color: #000000;
# }
# #T_c04f1_row0_col15 {
# ...

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  float64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  float64
# ...

# %%
credit[credit.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ID, LIMIT_BAL, SEX, EDUCATION, MARRIAGE, AGE, PAY_0, PAY_2, PAY_3, PAY_4, PAY_5, PAY_6, BILL_AMT1, BILL_AMT2, BILL_AMT3, BILL_AMT4, BILL_AMT5, BILL_AMT6, PAY_AMT1, PAY_AMT2, PAY_AMT3, PAY_AMT4, PAY_AMT5, PAY_AMT6, default.payment.next.month]
# Index: []
#
# [0 rows x 25 columns]

# %%
credit.isna().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default.payment.next.month    0
# dtype: int64

# %%
plt.figure(figsize=(20,6))
sns.countplot(x=credit['AGE'], data=credit)
plt.show()

# %%
plt.figure(figsize=(20,6))
sns.countplot(x=credit['SEX'],data=credit)
plt.show()

# %%
plt.figure(figsize=(20,6))
sns.countplot(x=credit['LIMIT_BAL'],data=credit)
plt.show()

# %%
plt.figure(figsize=(20,6))
sns.countplot(x=credit['default.payment.next.month'],data=credit)
plt.show()

# %%
credit.drop(columns=['ID'], inplace=True)

# %%
credit.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0    20000.0    2          2         1   24      2      2     -1     -1
# 1   120000.0    2          2         2   26     -1      2      0      0
# 2    90000.0    2          2         2   34      0      0      0      0
# 3    50000.0    2          2         1   37      0      0      0      0
# 4    50000.0    1          2         1   57     -1      0     -1      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0     -2  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1      0  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2      0  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3      0  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 4      0  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# ...

# %%
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def calc_vif(x):
    vif=pd.DataFrame()
    vif['column']=x.columns
    vif['vif']=[variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
    return vif

# %%
calc_vif(credit)
# Out:
#                         column        vif
# 0                    LIMIT_BAL   4.037689
# 1                          SEX   9.104408
# 2                    EDUCATION   6.731120
# 3                     MARRIAGE   6.286033
# 4                          AGE  11.051266
# 5                        PAY_0   1.996611
# 6                        PAY_2   3.215337
# 7                        PAY_3   3.728916
# 8                        PAY_4   4.440215
# 9                        PAY_5   4.986146
# 10                       PAY_6   3.463801
# 11                   BILL_AMT1  20.844022
# 12                   BILL_AMT2  38.215437
# 13                   BILL_AMT3  31.783047
# 14                   BILL_AMT4  29.548255
# 15                   BILL_AMT5  35.986380
# 16                   BILL_AMT6  21.426512
# 17                    PAY_AMT1   1.908571
# 18                    PAY_AMT2   2.385014
# 19                    PAY_AMT3   1.911695
# 20                    PAY_AMT4   1.805139
# ...

# %%
credit.drop(['BILL_AMT2'],axis=1,inplace=True)

# %%
calc_vif(credit)
# Out:
#                         column        vif
# 0                    LIMIT_BAL   4.037059
# 1                          SEX   9.103770
# 2                    EDUCATION   6.731088
# 3                     MARRIAGE   6.285422
# 4                          AGE  11.051249
# 5                        PAY_0   1.996499
# 6                        PAY_2   3.215333
# 7                        PAY_3   3.720350
# 8                        PAY_4   4.439367
# 9                        PAY_5   4.985553
# 10                       PAY_6   3.463111
# 11                   BILL_AMT1  10.016899
# 12                   BILL_AMT3  24.156045
# 13                   BILL_AMT4  29.546002
# 14                   BILL_AMT5  35.978888
# 15                   BILL_AMT6  21.355493
# 16                    PAY_AMT1   1.399689
# 17                    PAY_AMT2   1.911699
# 18                    PAY_AMT3   1.909030
# 19                    PAY_AMT4   1.803585
# 20                    PAY_AMT5   1.846681
# ...

# %%
credit.drop(['BILL_AMT5'],axis=1,inplace=True)

# %%
calc_vif(credit)
# Out:
#                         column        vif
# 0                    LIMIT_BAL   4.032029
# 1                          SEX   9.102380
# 2                    EDUCATION   6.730377
# 3                     MARRIAGE   6.284864
# 4                          AGE  11.051249
# 5                        PAY_0   1.996147
# 6                        PAY_2   3.215187
# 7                        PAY_3   3.720331
# 8                        PAY_4   4.434756
# 9                        PAY_5   4.980631
# 10                       PAY_6   3.460708
# 11                   BILL_AMT1  10.013962
# 12                   BILL_AMT3  24.116407
# 13                   BILL_AMT4  22.756869
# 14                   BILL_AMT6  10.952189
# 15                    PAY_AMT1   1.399394
# 16                    PAY_AMT2   1.908089
# 17                    PAY_AMT3   1.901625
# 18                    PAY_AMT4   1.430386
# 19                    PAY_AMT5   1.476609
# 20                    PAY_AMT6   1.254944
# ...

# %%
credit.drop(['BILL_AMT3'],axis=1,inplace=True)
calc_vif(credit)
# Out:
#                         column        vif
# 0                    LIMIT_BAL   4.030141
# 1                          SEX   9.102372
# 2                    EDUCATION   6.729816
# 3                     MARRIAGE   6.284430
# 4                          AGE  11.051044
# 5                        PAY_0   1.996147
# 6                        PAY_2   3.212938
# 7                        PAY_3   3.706790
# 8                        PAY_4   4.433996
# 9                        PAY_5   4.977624
# 10                       PAY_6   3.460410
# 11                   BILL_AMT1   6.588130
# 12                   BILL_AMT4  15.178649
# 13                   BILL_AMT6  10.901794
# 14                    PAY_AMT1   1.369889
# 15                    PAY_AMT2   1.299722
# 16                    PAY_AMT3   1.441976
# 17                    PAY_AMT4   1.429712
# 18                    PAY_AMT5   1.476588
# 19                    PAY_AMT6   1.254866
# 20  default.payment.next.month   1.450848

# %%
credit.drop(['BILL_AMT4'],axis=1,inplace=True)
calc_vif(credit)
# Out:
#                         column        vif
# 0                    LIMIT_BAL   4.022444
# 1                          SEX   9.101414
# 2                    EDUCATION   6.729525
# 3                     MARRIAGE   6.284343
# 4                          AGE  11.051006
# 5                        PAY_0   1.996095
# 6                        PAY_2   3.210470
# 7                        PAY_3   3.706351
# 8                        PAY_4   4.427139
# 9                        PAY_5   4.964638
# 10                       PAY_6   3.454647
# 11                   BILL_AMT1   4.660579
# 12                   BILL_AMT6   5.124640
# 13                    PAY_AMT1   1.347897
# 14                    PAY_AMT2   1.262657
# 15                    PAY_AMT3   1.309654
# 16                    PAY_AMT4   1.283671
# 17                    PAY_AMT5   1.321034
# 18                    PAY_AMT6   1.236355
# 19  default.payment.next.month   1.450847

# %%
credit.drop(['AGE'],axis=1,inplace=True)
calc_vif(credit)
# Out:
#                         column       vif
# 0                    LIMIT_BAL  3.621731
# 1                          SEX  8.136292
# 2                    EDUCATION  5.039461
# 3                     MARRIAGE  6.140596
# 4                        PAY_0  1.996061
# 5                        PAY_2  3.210464
# 6                        PAY_3  3.706349
# 7                        PAY_4  4.427109
# 8                        PAY_5  4.962693
# 9                        PAY_6  3.454262
# 10                   BILL_AMT1  4.660023
# 11                   BILL_AMT6  5.124329
# 12                    PAY_AMT1  1.347673
# 13                    PAY_AMT2  1.262654
# 14                    PAY_AMT3  1.309634
# 15                    PAY_AMT4  1.283651
# 16                    PAY_AMT5  1.320931
# 17                    PAY_AMT6  1.236123
# 18  default.payment.next.month  1.425422

# %%
credit.drop(['SEX'],axis=1,inplace=True)
calc_vif(credit)
# Out:
#                         column       vif
# 0                    LIMIT_BAL  3.387600
# 1                    EDUCATION  3.945431
# 2                     MARRIAGE  4.499591
# 3                        PAY_0  1.996061
# 4                        PAY_2  3.209961
# 5                        PAY_3  3.706165
# 6                        PAY_4  4.426773
# 7                        PAY_5  4.961222
# 8                        PAY_6  3.454249
# 9                    BILL_AMT1  4.654522
# 10                   BILL_AMT6  5.117214
# 11                    PAY_AMT1  1.347592
# 12                    PAY_AMT2  1.262628
# 13                    PAY_AMT3  1.309271
# 14                    PAY_AMT4  1.283598
# 15                    PAY_AMT5  1.320554
# 16                    PAY_AMT6  1.236095
# 17  default.payment.next.month  1.415122

# %%
credit.drop(['BILL_AMT6'],axis=1,inplace=True)
calc_vif(credit)
# Out:
#                         column       vif
# 0                    LIMIT_BAL  3.339442
# 1                    EDUCATION  3.944895
# 2                     MARRIAGE  4.497868
# 3                        PAY_0  1.995519
# 4                        PAY_2  3.207143
# 5                        PAY_3  3.705975
# 6                        PAY_4  4.426060
# 7                        PAY_5  4.957406
# 8                        PAY_6  3.393287
# 9                    BILL_AMT1  1.983685
# 10                    PAY_AMT1  1.342239
# 11                    PAY_AMT2  1.258114
# 12                    PAY_AMT3  1.295290
# 13                    PAY_AMT4  1.253909
# 14                    PAY_AMT5  1.218514
# 15                    PAY_AMT6  1.209694
# 16  default.payment.next.month  1.414875

# %%
X=credit.iloc[:,:-1]
y=credit.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.45,train_size=0.55,random_state=90)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf=DecisionTreeClassifier(criterion='entropy',max_depth=20,splitter='best',random_state=102,min_samples_split=5,ccp_alpha=0.01)
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.01, criterion='entropy', max_depth=20,
#                        min_samples_split=5, random_state=102)

# %%
print('the model test score',clf.score(X_test,y_test))
print('the model train score',clf.score(X_train,y_train))
# Out:
# the model test score 0.8213333333333334
# the model train score 0.8181818181818182

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model=RandomForestClassifier(n_estimators=10,max_depth=5,n_jobs=-1,random_state=105,criterion='entropy')
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=5, n_estimators=10,
#                        n_jobs=-1, random_state=105)

# %%
print('model test_score',model.score(X_test,y_test))
print('model train_score',model.score(X_train,y_train))
# Out:
# model test_score 0.8211111111111111
# model train_score 0.823939393939394

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %%
pred=model.predict(X_test)

# %%
print("Accuracy score",accuracy_score(y_test,pred))
# Out:
# Accuracy score 0.8211111111111111

# %%
metrix=confusion_matrix(y_test,pred)
metrix
# Out:
# array([[10022,   508],
#        [ 1907,  1063]], dtype=int64)

# %%
from sklearn.naive_bayes import BernoulliNB

# %%
model=BernoulliNB(binarize=0.2,alpha=0.5,fit_prior=True,class_prior=None)
model.fit(X_train,y_train)
# Out:
# BernoulliNB(alpha=0.5, binarize=0.2)

# %%
print('model test score',model.score(X_test,y_test))
print('model train score',model.score(X_train,y_train))
# Out:
# model test score 0.7821481481481481
# model train score 0.7824848484848484
